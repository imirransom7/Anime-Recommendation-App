# %% [markdown]
# # Genre Anime CSV
# I am going to make a new csv that will have field names with the corresponding genres in the `final_animedataset.csv` file. This will help with a better analysis and visualization for my tableau dashboard.
# This will also help with querying through the data for the application when showing the different genres that are associated with the anime

# %%
import pandas as pd
# Out:
# C:\Users\RhaMo\AppData\Local\Temp\ipykernel_28560\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('E:/RhaMo/CSV Files/Anime Dataset/final_animedataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35305695 entries, 0 to 35305694
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   username    object
#  1   anime_id    int64
#  2   my_score    int64
#  3   user_id     int64
#  4   gender      object
#  5   title       object
#  6   type        object
#  7   source      object
#  8   score       float64
#  9   scored_by   int64
#  10  rank        float64
#  11  popularity  int64
#  12  genre       object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 3.4+ GB

# %%
genres = df['genre']
genres
# Out:
# 0           Action, Adventure, Comedy, Super Power, Drama,...
# 1               Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen
# 2                         Comedy, School, Shoujo, Super Power
# 3           Slice of Life, Comedy, Drama, Romance, Fantasy...
# 4                      Magic, Comedy, Romance, School, Shoujo
#                                   ...
# 35305690                                               Hentai
# 35305691                     Adventure, Comedy, Harem, Hentai
# 35305692                                          Kids, Drama
# 35305693                                               Hentai
# 35305694                                               Hentai
# Name: genre, Length: 35305695, dtype: object

# %% [markdown]
# ## Transforming the Data
# I am going to make a set to get all the unique genres from the csv since they way the genres are set up in the `final_animedataset.csv` is inconvenient

# %%
new_set = set({})
for i in df['genre'].unique():
    print(i)
# Out:
# Action, Adventure, Comedy, Super Power, Drama, Fantasy, Shounen
# Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen
# Comedy, School, Shoujo, Super Power
# Slice of Life, Comedy, Drama, Romance, Fantasy, Shoujo
# Magic, Comedy, Romance, School, Shoujo
# Slice of Life, Comedy, Martial Arts, Fantasy
# Adventure, Comedy, Drama, Magic, Romance, Fantasy, School, Shoujo
# Comedy, Sci-Fi, Shoujo
# Action, Adventure, Comedy, Historical, Demons, Supernatural, Magic, Romance, Fantasy, Shounen
# Action, Adventure, Comedy, Super Power, Supernatural, Shounen
# Comedy, Drama, Magic, Romance, Fantasy
# Comedy, Harem, Romance, School, Shoujo
# Action, Comedy, Ecchi, Shounen, Sports
# Adventure, Fantasy, Comedy, Romance, Historical, Drama
# Slice of Life, Comedy, Ecchi, School, Seinen
# Action, Magic, Fantasy, Supernatural, Demons, Historical, Shoujo
# Comedy, Horror, Mystery, Shoujo, Supernatural
# Comedy, Drama, Harem, Magic, Music, Romance, School, Shoujo
# ...

# %% [markdown]
# ### New Approach
# Going to make a function that will store the anime's title and anime's id as values for the genre fileds if that anime has that genre in the `final_animedataset.csv`

# %%
grouped = df.groupby(['title', 'genre']).score.size().reset_index()
grouped
# Out:
#                                           title  \
# 0                                           "0"
# 1     "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi
# 2                      "Bungaku Shoujo" Memoire
# 3                        "Bungaku Shoujo" Movie
# 4                                        "Eiji"
# ...                                         ...
# 8736    xxxHOLiC Movie: Manatsu no Yoru no Yume
# 8737                               xxxHOLiC Rou
# 8738                          xxxHOLiC Shunmuki
# 8739                                    ēlDLIVE
# 8740                                          ◯
#
#                                                   genre  score
# 0                                                 Music    501
# 1                               Comedy, Fantasy, School   3798
# 2                                Drama, Romance, School   4442
# 3                       Mystery, Drama, Romance, School   9073
# 4                                 Comedy, Drama, Sports    257
# ...

# %%
titles = dict(grouped)['title']
titles
# Out:
# 0                                             "0"
# 1       "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi
# 2                        "Bungaku Shoujo" Memoire
# 3                          "Bungaku Shoujo" Movie
# 4                                          "Eiji"
#                           ...
# 8736      xxxHOLiC Movie: Manatsu no Yoru no Yume
# 8737                                 xxxHOLiC Rou
# 8738                            xxxHOLiC Shunmuki
# 8739                                      ēlDLIVE
# 8740                                            ◯
# Name: title, Length: 8741, dtype: object

# %%
genres1 = dict(grouped)['genre']
genres1
# Out:
# 0                                                   Music
# 1                                 Comedy, Fantasy, School
# 2                                  Drama, Romance, School
# 3                         Mystery, Drama, Romance, School
# 4                                   Comedy, Drama, Sports
#                               ...
# 8736    Mystery, Comedy, Psychological, Supernatural, ...
# 8737                                Mystery, Supernatural
# 8738    Mystery, Comedy, Psychological, Supernatural, ...
# 8739                        Action, Sci-Fi, Space, Police
# 8740                                      Dementia, Music
# Name: genre, Length: 8741, dtype: object

# %% [markdown]
# ### Transforming into Dictionaries
# Stopped using grouped because I realized that it is not needed.
# I have now made the values of the columns `title` and `genre` into list and made the anime titles the key of a new dictionary
# and the genres are the values for each of the anime titles

# %%
# new_dict = {}
# for i in range(len(titles)):
#     new_dict[titles[i]] = genres[i]
# new_dict

# %%
title = list(df['title'])
title
# Out:
# ['One Piece',
#  'Chobits',
#  'Gakuen Alice',
#  'Fruits Basket',
#  'Ultra Maniac',
#  'Ranma ½',
#  'Cardcaptor Sakura',
#  'Daa! Daa! Daa!',
#  'InuYasha',
#  'Bleach',
#  'Princess Tutu',
#  'Ouran Koukou Host Club',
#  'Air Gear',
#  'Saiunkoku Monogatari',
#  'Crayon Shin-chan',
#  'Shounen Onmyouji',
#  'Ghost Hunt',
#  'Kiniro no Corda: Primo Passo',
#  'Nodame Cantabile',
#  'Naruto: Shippuuden',
#  'Saiunkoku Monogatari 2nd Season',
#  'Glass no Kamen (2005)',
#  'Seto no Hanayome',
#  'Code-E',
#  'Shakugan no Shana II (Second)',
#  'Junjou Romantica',
#  'Itazura na Kiss',
#  'Toradora!',
#  'Nodame Cantabile: Paris-hen',
#  'Skip Beat!',
#  'Junjou Romantica 2',
#  'Shugo Chara!! Doki',
#  'Nodame Cantabile Finale',
#  'Hanasakeru Seishounen',
#  'Kimi ni Todoke',
#  'Yume-iro Pâtissière',
#  'Chu-Bra!!',
#  'Kaichou wa Maid-sama!',
#  'Bakuman.',
#  'B-gata H-kei',
#  'Beelzebub',
#  'Kimi ni Todoke 2nd Season',
#  'SKET Dance',
#  'Sekaiichi Hatsukoi',
# ...

# %% [markdown]
# Changing anything inside the genre column to a string to make sure I can later get all the unique genres

# %%
df['genre'] = df['genre'].astype(str).fillna('')
genre = list(df['genre'])
genre
# Out:
# ['Action, Adventure, Comedy, Super Power, Drama, Fantasy, Shounen',
#  'Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen',
#  'Comedy, School, Shoujo, Super Power',
#  'Slice of Life, Comedy, Drama, Romance, Fantasy, Shoujo',
#  'Magic, Comedy, Romance, School, Shoujo',
#  'Slice of Life, Comedy, Martial Arts, Fantasy',
#  'Adventure, Comedy, Drama, Magic, Romance, Fantasy, School, Shoujo',
#  'Comedy, Sci-Fi, Shoujo',
#  'Action, Adventure, Comedy, Historical, Demons, Supernatural, Magic, Romance, Fantasy, Shounen',
#  'Action, Adventure, Comedy, Super Power, Supernatural, Shounen',
#  'Comedy, Drama, Magic, Romance, Fantasy',
#  'Comedy, Harem, Romance, School, Shoujo',
#  'Action, Comedy, Ecchi, Shounen, Sports',
#  'Adventure, Fantasy, Comedy, Romance, Historical, Drama',
#  'Slice of Life, Comedy, Ecchi, School, Seinen',
#  'Action, Magic, Fantasy, Supernatural, Demons, Historical, Shoujo',
#  'Comedy, Horror, Mystery, Shoujo, Supernatural',
# ...

# %%
new_dict = {}
for i in range(len(title)):
    new_dict[title[i]] = genre[i]
new_dict
# Out:
# {'One Piece': 'Action, Adventure, Comedy, Super Power, Drama, Fantasy, Shounen',
#  'Chobits': 'Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen',
#  'Gakuen Alice': 'Comedy, School, Shoujo, Super Power',
#  'Fruits Basket': 'Slice of Life, Comedy, Drama, Romance, Fantasy, Shoujo',
#  'Ultra Maniac': 'Magic, Comedy, Romance, School, Shoujo',
#  'Ranma ½': 'Slice of Life, Comedy, Martial Arts, Fantasy',
#  'Cardcaptor Sakura': 'Adventure, Comedy, Drama, Magic, Romance, Fantasy, School, Shoujo',
#  'Daa! Daa! Daa!': 'Comedy, Sci-Fi, Shoujo',
#  'InuYasha': 'Action, Adventure, Comedy, Historical, Demons, Supernatural, Magic, Romance, Fantasy, Shounen',
#  'Bleach': 'Action, Adventure, Comedy, Super Power, Supernatural, Shounen',
#  'Princess Tutu': 'Comedy, Drama, Magic, Romance, Fantasy',
#  'Ouran Koukou Host Club': 'Comedy, Harem, Romance, School, Shoujo',
#  'Air Gear': 'Action, Comedy, Ecchi, Shounen, Sports',
# ...

# %% [markdown]
# A dictionary comprehension that takes the list of anime titles and inserts it as the key for the new dictionary from its indeex, and the genre as the value from it's index as well

# %%
anime_dict = {title[i]:genre[i] for i in range(len(title))}
anime_dict
# Out:
# {'One Piece': 'Action, Adventure, Comedy, Super Power, Drama, Fantasy, Shounen',
#  'Chobits': 'Sci-Fi, Comedy, Drama, Romance, Ecchi, Seinen',
#  'Gakuen Alice': 'Comedy, School, Shoujo, Super Power',
#  'Fruits Basket': 'Slice of Life, Comedy, Drama, Romance, Fantasy, Shoujo',
#  'Ultra Maniac': 'Magic, Comedy, Romance, School, Shoujo',
#  'Ranma ½': 'Slice of Life, Comedy, Martial Arts, Fantasy',
#  'Cardcaptor Sakura': 'Adventure, Comedy, Drama, Magic, Romance, Fantasy, School, Shoujo',
#  'Daa! Daa! Daa!': 'Comedy, Sci-Fi, Shoujo',
#  'InuYasha': 'Action, Adventure, Comedy, Historical, Demons, Supernatural, Magic, Romance, Fantasy, Shounen',
#  'Bleach': 'Action, Adventure, Comedy, Super Power, Supernatural, Shounen',
#  'Princess Tutu': 'Comedy, Drama, Magic, Romance, Fantasy',
#  'Ouran Koukou Host Club': 'Comedy, Harem, Romance, School, Shoujo',
#  'Air Gear': 'Action, Comedy, Ecchi, Shounen, Sports',
# ...

# %%
anime_dict.get('One Piece')
# Out:
# 'Action, Adventure, Comedy, Super Power, Drama, Fantasy, Shounen'

# %% [markdown]
# Here I make a loop and a nested for loop to get the unique genres

# %%
se = set({})
for value in anime_dict.values():
    for v in value.split(','):
        # Using strip here because there was whitespace in some strings which
        # made so there were techincally duplicates
        se.add(v.strip())
unique_genres = sorted(list(se))

# %%
unique_genres
# Out:
# ['Action',
#  'Adventure',
#  'Cars',
#  'Comedy',
#  'Dementia',
#  'Demons',
#  'Drama',
#  'Ecchi',
#  'Fantasy',
#  'Game',
#  'Harem',
#  'Hentai',
#  'Historical',
#  'Horror',
#  'Josei',
#  'Kids',
#  'Magic',
#  'Martial Arts',
#  'Mecha',
#  'Military',
#  'Music',
#  'Mystery',
#  'Parody',
#  'Police',
#  'Psychological',
#  'Romance',
#  'Samurai',
#  'School',
#  'Sci-Fi',
#  'Seinen',
#  'Shoujo',
#  'Shoujo Ai',
#  'Shounen',
#  'Shounen Ai',
#  'Slice of Life',
#  'Space',
#  'Sports',
#  'Super Power',
#  'Supernatural',
#  'Thriller',
#  'Vampire',
#  'Yaoi',
#  'Yuri',
#  'nan']

# %%
len(unique_genres)
# Out:
# 44

# %% [markdown]
# ## Creating Genre Dictionary
# Making the genre dictionary so that I can turn it into a dataframe and then into a csv file

# %% [markdown]
# ### Genre Funciton
# I am going to create a fucntion to help auotmate the process; the keys are the genres, and the values will be all the anime associated with the genere

# %% [markdown]
# I will then interate through a list to automate the process of making the genre dicitonary

# %%
genre_dict = {}

from pandas import Series, DataFrame
def genre_function(name: str) -> str:
    values_list = []
    for key, value in anime_dict.items():
        if name in value:
            values_list.append(key)
    # Converting into a Series to make a DataFrame even with the arrays not being the same length
    return Series(values_list)


for ug in unique_genres:
    genre_function(ug)
    genre_dict[ug] = genre_function(ug)
genre_dict
# Out:
# {'Action': 0                                           One Piece
#  1                                            InuYasha
#  2                                              Bleach
#  3                                            Air Gear
#  4                                    Shounen Onmyouji
#                              ...
#  2487                           Yao Shen Ji 2nd Season
#  2488                                     Ariel Deluxe
#  2489    Choujuu Kishin Dancougar: God Bless Dancougar
#  2490                Kamen Rider Den-O: Imagin Anime 2
#  2491               Starship Troopers: Traitor of Mars
#  Length: 2492, dtype: object,
#  'Adventure': 0                                               One Piece
#  1                                       Cardcaptor Sakura
#  2                                                InuYasha
#  3                                                  Bleach
#  4                                    Saiunkoku Monogatari
# ...

# %%
data = DataFrame(genre_dict)
data
# Out:
#                 Action             Adventure                     Cars  \
# 0            One Piece             One Piece   Initial D Fourth Stage
# 1             InuYasha     Cardcaptor Sakura    Initial D First Stage
# 2               Bleach              InuYasha  F-Zero: Falcon Densetsu
# 3             Air Gear                Bleach                  Redline
# 4     Shounen Onmyouji  Saiunkoku Monogatari            Redline Pilot
# ...                ...                   ...                      ...
# 3471               NaN                   NaN                      NaN
# 3472               NaN                   NaN                      NaN
# 3473               NaN                   NaN                      NaN
# 3474               NaN                   NaN                      NaN
# 3475               NaN                   NaN                      NaN
#
#                                                  Comedy  \
# 0                                             One Piece
# ...

# %%
data.to_csv("E:\RhaMo\CSV Files\Anime Dataset\genre_dataset_1.csv")

# %% [markdown]
# Using this to make sure my function is working as expected

# %%
# df['title'] + ": " + df['genre']

# %%
genres_dict = {}


def genres_function(name: str) -> str:
    values_list = []
    for key, value in anime_dict.items():
        if name in value:
            # This makes the strings more readable
            values_list.append(key+', ')
    # Converting list to a string, for if left a list, the arrays will not be the same length
    return "".join(values_list)


for ug in unique_genres:
    genres_function(ug)
    genres_dict[ug] = genres_function(ug)
genres_dict
# Out:
# {'Action': 'One Piece, InuYasha, Bleach, Air Gear, Shounen Onmyouji, Naruto: Shippuuden, Shakugan no Shana II (Second), Beelzebub, Accel World, Cowboy Bebop, Witch Hunter Robin, Naruto, Sunabouzu, Texhnolyze, Neon Genesis Evangelion, Kenpuu Denki Berserk, Ghost in the Shell, Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen, Rurouni Kenshin: Meiji Kenkaku Romantan, Akira, Chrno Crusade, Mobile Suit Gundam SEED, Fullmetal Alchemist, Saiyuuki Reload, Saiyuuki Reload Gunlock, Gunslinger Girl, Hunter x Hunter, Loveless, Blood+, Juuni Kokuki, Mononoke Hime, RahXephon, Speed Grapher, Wolf&#039;s Rain, Samurai Champloo, R.O.D OVA, R.O.D the TV, Elfen Lied, FLCL, Hellsing, A Kite, Shakugan no Shana, Fate/stay night, Gantz, Yuu☆Yuu☆Hakusho, Gantz 2nd Stage, Phantom The Animation, Ghost in the Shell: Stand Alone Complex, Kurau Phantom Memory, Kino no Tabi: The Beautiful World, Vampire Hunter D (2000), Naruto: Takigakure no Shitou - Ore ga Eiyuu Dattebayo!, Vampire Hunter D, Bleach: Memorie
# ...

# %%
new_df = pd.DataFrame(genres_dict, index=[0])
new_df
# Out:
#                                               Action  \
# 0  One Piece, InuYasha, Bleach, Air Gear, Shounen...
#
#                                            Adventure  \
# 0  One Piece, Cardcaptor Sakura, InuYasha, Bleach...
#
#                                                 Cars  \
# 0  Initial D Fourth Stage, Initial D First Stage,...
#
#                                               Comedy  \
# 0  One Piece, Chobits, Gakuen Alice, Fruits Baske...
#
#                                             Dementia  \
# 0  Neon Genesis Evangelion, Neon Genesis Evangeli...
#
#                                               Demons  \
# 0  InuYasha, Shounen Onmyouji, Beelzebub, Kamisam...
#
#                                                Drama  \
# 0  One Piece, Chobits, Fruits Basket, Cardcaptor ...
#
#                                                Ecchi  \
# 0  Chobits, Air Gear, Crayon Shin-chan, Chu-Bra!!...
#
#                                              Fantasy  \
# ...

# %%
new_df.to_csv("E:\RhaMo\CSV Files\Anime Dataset\genre_dataset_2.csv")

# %%
newer_df = pd.DataFrame.from_dict(genres_dict, orient='index', columns=['Genres'])
newer_df
# Out:
#                                                           Genres
# Action         One Piece, InuYasha, Bleach, Air Gear, Shounen...
# Adventure      One Piece, Cardcaptor Sakura, InuYasha, Bleach...
# Cars           Initial D Fourth Stage, Initial D First Stage,...
# Comedy         One Piece, Chobits, Gakuen Alice, Fruits Baske...
# Dementia       Neon Genesis Evangelion, Neon Genesis Evangeli...
# Demons         InuYasha, Shounen Onmyouji, Beelzebub, Kamisam...
# Drama          One Piece, Chobits, Fruits Basket, Cardcaptor ...
# Ecchi          Chobits, Air Gear, Crayon Shin-chan, Chu-Bra!!...
# Fantasy        One Piece, Fruits Basket, Ranma ½, Cardcaptor ...
# Game           Chihayafuru, Accel World, Chihayafuru 2, Hikar...
# Harem          Ouran Koukou Host Club, Kiniro no Corda: Primo...
# Hentai         A Kite, Enzai, Sensitive Pornograph, Boku no P...
# Historical     InuYasha, Saiunkoku Monogatari, Shounen Onmyou...
# ...

# %%
newer_df.to_csv("E:\RhaMo\CSV Files\Anime Dataset\genre_dataset_3.csv")

# %%
unique_genres.append('UNKNOWN')
unique_genres.append('Award Winning')
print(unique_genres, end='')
# Out:
# ['Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri', 'nan', 'UNKNOWN', 'UNKNOWN', 'Award Winning']

# %%
import re
def genre_separation(genre):
    for g in unique_genres:
        if re.search(rf'{g}', genre):
            return g

df['separated_genre'] = df['genre'].apply(genre_separation)
df
# Out:
#                  username  anime_id  my_score  user_id  gender  \
# 0                karthiga        21         9  2255153  Female
# 1                karthiga        59         7  2255153  Female
# 2                karthiga        74         7  2255153  Female
# 3                karthiga       120         7  2255153  Female
# 4                karthiga       178         7  2255153  Female
# ...                   ...       ...       ...      ...     ...
# 35305690  Destoria-LeVaun      3250        10   266038  Female
# 35305691   MariiTrindade_      4340         0   537855  Female
# 35305692    mariapeterson      4515         6  1433359  Female
# 35305693          Nemo584      4730        10   443290    Male
# 35305694            karyy     12957         0  2846159  Female
#
#                                      title type    source  score  scored_by  \
# 0                                One Piece   TV     Manga   8.54     423868
# ...

# %%
df1 = pd.read_csv('E:/RhaMo/CSV Files/Anime Dataset/anime-dataset-2023.csv')
df1
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %%
df1['Separated Genres'] = df1['Genres'].apply(genre_separation)
df1
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# ...

# %%
df1['Name'] + ': ' + df1['Separated Genres']
# Out:
# 0                           Cowboy Bebop: Action
# 1        Cowboy Bebop: Tengoku no Tobira: Action
# 2                                 Trigun: Action
# 3                     Witch Hunter Robin: Action
# 4                      Bouken Ou Beet: Adventure
#                           ...
# 24900                        Wu Nao Monu: Comedy
# 24901                Bu Xing Si: Yuan Qi: Action
# 24902                        Di Yi Xulie: Action
# 24903          Bokura no Saishuu Sensou: UNKNOWN
# 24904                    Shijuuku Nichi: UNKNOWN
# Length: 24905, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24905 non-null  int64
#  1   Name              24905 non-null  object
#  2   English name      24905 non-null  object
#  3   Other name        24905 non-null  object
#  4   Score             24905 non-null  object
#  5   Genres            24905 non-null  object
#  6   Synopsis          24905 non-null  object
#  7   Type              24905 non-null  object
#  8   Episodes          24905 non-null  object
#  9   Aired             24905 non-null  object
#  10  Premiered         24905 non-null  object
#  11  Status            24905 non-null  object
#  12  Producers         24905 non-null  object
#  13  Licensors         24905 non-null  object
#  14  Studios           24905 non-null  object
#  15  Source            24905 non-null  object
# ...
